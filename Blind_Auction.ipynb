# %%
logo = '''
                         ___________
                         \         /
                          )_______(
                          |"""""""|_.-._,.---------.,_.-._
                          |       | | |               | | ''-.
                          |       |_| |_             _| |_..-'
                          |_______| '-' `'---------'` '-'
                          )"""""""(
                         /_________\\
                       .-------------.
                      /_______________\\
'''
print(logo)

bid ={}
def find_highest_bidder(bidding_dictionary):
    highest_bid = 0
    winner = ""
    for bidder in bidding_dictionary:
        bid_amount = bidding_dictionary[bidder]
        if bid_amount > highest_bid:
            highest_bid = bid_amount
        winner = bidder
    print(f"The winner is {winner} and highest bid is {highest_bid}")  
bidding_finished = False
while not bidding_finished:
    bidder_name = input("What is your name: ")
    bid_price = float(input("What is your bid amount: $"))
    bid[bidder_name] = bid_price
    should_continue = input("Is there any bidders left 'yes' or 'no'. \n").lower()
    if should_continue == "no":
        bidding_finished = True
        find_highest_bidder(bid)
    elif should_continue == 'yes':
        bidding_finished = False
        print("\n"*30)
# Out:
#                          ___________
#                          \         /
#                           )_______(
#                           |"""""""|_.-._,.---------.,_.-._
#                           |       | | |               | | ''-.
#                           |       |_| |_             _| |_..-'
#                           |_______| '-' `'---------'` '-'
#                           )"""""""(
#                          /_________\
#                        .-------------.
#                       /_______________\
#
# What is your name: nany
# What is your bid amount: $76
# Is there any bidders left 'yes' or 'no'.
# yes
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# What is your name: shyam
# What is your bid amount: $65
# Is there any bidders left 'yes' or 'no'.
# no
# The winner is shyam and highest bid is 76.0
